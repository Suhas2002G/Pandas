# %%
import pandas as pd

# %%
df = pd.read_csv('./uncleaned_data.csv')

# %% [markdown]
# ### Exploring Data

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           NaN            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           NaN  Iris-setosa

# %%
df.tail()  # last 5 records
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.info()   # Column names, dtypes, memory
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  147 non-null    float64
#  2   SepalWidthCm   147 non-null    float64
#  3   PetalLengthCm  146 non-null    float64
#  4   PetalWidthCm   148 non-null    float64
#  5   Species        147 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()   # Summary statistics (mean, std, min, max).
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     147.000000    147.000000     146.000000    148.000000
# mean    75.500000       5.867347      3.045578       3.821918      1.212162
# std     43.445368       0.817628      0.432456       1.745753      0.759332
# min      1.000000       4.400000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.400000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.shape      # (rows, columns)
# Out:
# (150, 6)

# %%
df.dtypes    # Data types
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['Id',
#  'SepalLengthCm',
#  'SepalWidthCm',
#  'PetalLengthCm',
#  'PetalWidthCm',
#  'Species']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.isnull().sum()  # Count missing values column-wise
# Out:
# Id               0
# SepalLengthCm    3
# SepalWidthCm     3
# PetalLengthCm    4
# PetalWidthCm     2
# Species          3
# dtype: int64

# %% [markdown]
# ### Selection and Filtration

# %%
df['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df[['SepalLengthCm', 'PetalLengthCm']]
# Out:
#      SepalLengthCm  PetalLengthCm
# 0              5.1            1.4
# 1              4.9            1.4
# 2              4.7            1.3
# 3              4.6            1.5
# 4              5.0            1.4
# ..             ...            ...
# 145            6.7            5.2
# 146            6.3            5.0
# 147            6.5            5.2
# 148            6.2            5.4
# 149            5.9            5.1
#
# [150 rows x 2 columns]

# %%
df.loc[1]
# Out:
# Id                         2
# SepalLengthCm            4.9
# SepalWidthCm             3.0
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 1, dtype: object

# %%
df.loc[[0,1,2,3]]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           NaN            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa

# %%
df.query("SepalLengthCm > 4 and SepalLengthCm < 5")
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           NaN            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            NaN           0.1
# 22    23            4.6           3.6            1.0           0.2
# 24    25            4.8           NaN            1.9           0.2
# 29    30            4.7           3.2            1.6           0.2
# 30    31            4.8           3.1            1.6           0.2
# 34    35            4.9           3.1            1.5           0.1
# 37    38            4.9           3.1            1.5           0.1
# ...

# %% [markdown]
# ### Modification n

# %%
df['Price'] = df['SepalLengthCm'] * df['PetalLengthCm']

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           NaN            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           NaN
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  Price
# 0       Iris-setosa   7.14
# 1       Iris-setosa   6.86
# 2       Iris-setosa   6.11
# 3       Iris-setosa   6.90
# ...

# %%
df.columns.to_list()
# Out:
# ['Id',
#  'SepalLengthCm',
#  'SepalWidthCm',
#  'PetalLengthCm',
#  'PetalWidthCm',
#  'Species',
#  'Price']

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    3
# SepalWidthCm     3
# PetalLengthCm    4
# PetalWidthCm     2
# Species          3
# Price            7
# dtype: int64

# %%
df.drop(columns=['Price'], inplace=True)   # Drop particular column

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           NaN            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           NaN
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.rename(columns={'Id':'IRIS_ID'})
# Out:
#      IRIS_ID  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0          1            5.1           3.5            1.4           0.2
# 1          2            4.9           3.0            1.4           0.2
# 2          3            4.7           NaN            1.3           0.2
# 3          4            4.6           3.1            1.5           0.2
# 4          5            5.0           3.6            1.4           NaN
# ..       ...            ...           ...            ...           ...
# 145      146            6.7           3.0            5.2           2.3
# 146      147            6.3           2.5            5.0           1.9
# 147      148            6.5           3.0            5.2           2.0
# 148      149            6.2           3.4            5.4           2.3
# 149      150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           NaN            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           NaN
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.fillna(value=0, inplace=True)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           0.0            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.0
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.dropna()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           0.0            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.0
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### Aggregation & Stats

# %%
df['SepalWidthCm'].min()
# Out:
# np.float64(0.0)

# %%
df['SepalWidthCm'].max()
# Out:
# np.float64(4.4)

# %%
df['SepalWidthCm'].median()
# Out:
# np.float64(3.0)

# %%
df['SepalWidthCm'].sum()
# Out:
# np.float64(447.70000000000005)

# %%
df['SepalWidthCm'].std()
# Out:
# np.float64(0.6052052363257134)

# %%
df['SepalWidthCm'].mean()
# Out:
# np.float64(2.984666666666667)

# %%
df.nunique()   # Count distinct values.
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      24
# PetalLengthCm     44
# PetalWidthCm      23
# Species            4
# dtype: int64
